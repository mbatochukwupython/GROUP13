# %%
# !git clone -l -s https://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@github.com/mbatochukwupython/GROUP13.git
# %cd GROUP13
# !dir
# Out:
# Cloning into 'GROUP13'...
# ...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), 25.05 KiB | 5.01 MiB/s, done.
# /content/GROUP13/GROUP13/GROUP13
# data_acquisition_d_rabaii.ipynb  group13.csv  Noise2.csv  README.md

# %%
import pandas as pd

xx = pd.read_csv('/content/Noise2.csv')    # csv files
#xx = pd.read_excel(Noise2.xlsx')

list(xx)  # get the list of column names
# Out:
#                              Place       Lat      Long   min   avg    max
# 0                 Ife grand resort  7.493056  4.483889  78.3  81.8   86.2
# 1                         Tollgate  7.493611  4.492222  67.9  89.4   91.1
# 2               Powerline junction  7.496389  4.505000  69.1  88.5   92.1
# 3                 Secretariete ife  7.496111  4.516667  82.2  90.2   92.7
# 4                   Glory to glory  7.491389  4.528056  77.2  89.2   94.8
# 5              Babcock Uni Med Tre  7.488889  4.540833  83.3  90.6   95.3
# 6                    Sabo bus stop  7.491389  4.556111  80.8  91.9   93.3
# 7             More  Police Station  7.490833  4.566667  87.5  90.6   93.9
# 8                 Ide ade junction  7.483889  4.562778  87.3  92.8   95.3
# 9              St peters cathedral  7.496389  4.555278  67.4  89.8   94.5
# 10              Lagere Zenith Bank  7.487222  4.545000  82.5  88.0   92.8
# 11                OAUTHC (Phase 1)  7.502452  4.571802  67.0  81.0   87.0
# ...

# %%
xx = pd.read_csv('/content/Noise2.csv',index_col='Place',usecols=['Place','Lat','Long',
                                                                'min','avg','max'])

xx
# Out:
#                                      Lat      Long   min   avg    max
# Place
# Ife grand resort                7.493056  4.483889  78.3  81.8   86.2
# Tollgate                        7.493611  4.492222  67.9  89.4   91.1
# Powerline junction              7.496389  4.505000  69.1  88.5   92.1
# Secretariete ife                7.496111  4.516667  82.2  90.2   92.7
# Glory to glory                  7.491389  4.528056  77.2  89.2   94.8
# Babcock Uni Med Tre             7.488889  4.540833  83.3  90.6   95.3
# Sabo bus stop                   7.491389  4.556111  80.8  91.9   93.3
# More  Police Station            7.490833  4.566667  87.5  90.6   93.9
# Ide ade junction                7.483889  4.562778  87.3  92.8   95.3
# St peters cathedral             7.496389  4.555278  67.4  89.8   94.5
# Lagere Zenith Bank              7.487222  4.545000  82.5  88.0   92.8
# OAUTHC (Phase 1)                7.502452  4.571802  67.0  81.0   87.0
# ...

# %%
# Basic statistics can also be performed smoothly

# Get summary statistics for each column
xx.describe()
# Out:
#              Lat       Long        min        avg         max
# count  24.000000  24.000000  24.000000  24.000000   24.000000
# mean    7.485175   4.517839  61.687500  80.712500   93.466667
# std     0.041835   0.055076  20.981821  10.369114    8.481625
# min     7.291170   4.311909   8.400000  58.000000   80.000000
# 25%     7.489047   4.501806  45.250000  74.500000   89.750000
# 50%     7.492222   4.530352  67.650000  82.400000   93.000000
# 75%     7.496649   4.553197  78.925000  89.500000   94.575000
# max     7.512100   4.571802  87.500000  92.800000  115.000000

# %% [markdown]
# # New Section

# %%
# some simple plotting
xx.plot()  # this plots all the column in one plot
# Out:
# <Axes: xlabel='Place'>

# %%
xx.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Place'>, <Axes: xlabel='Place'>,
#        <Axes: xlabel='Place'>, <Axes: xlabel='Place'>,
#        <Axes: xlabel='Place'>], dtype=object)
